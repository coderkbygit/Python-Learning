# %% [markdown]
# ## Image Visualization

# %%
import numpy as np # array

# %%
import matplotlib.pyplot as plt # visualization

# %%
from PIL import Image # python image library

# %%
SachinImage=Image.open(r"C:\Users\KULBKUS\Downloads\sachin.jpg") # r for raw String
SachinImage
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x348>

# %%
featherImage=Image.open(r"C:\Users\KULBKUS\Downloads\feather.jpg") # r for raw String
featherImage
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1543>

# %%
print(type(SachinImage))
print(type(featherImage))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
sachinArray = np.asarray(SachinImage)
sachinArray
# Out:
# array([[[ 33,  36,  29],
#         [ 34,  37,  30],
#         [ 36,  39,  32],
#         ...,
#         [ 42,  29,  21],
#         [ 51,  36,  29],
#         [ 53,  36,  29]],
#
#        [[ 33,  36,  29],
#         [ 34,  37,  30],
#         [ 35,  38,  31],
#         ...,
#         [ 42,  28,  19],
#         [ 51,  34,  26],
#         [ 52,  33,  26]],
#
#        [[ 33,  36,  29],
#         [ 33,  36,  29],
#         [ 34,  37,  30],
#         ...,
#         [ 46,  29,  21],
#         [ 57,  38,  31],
#         [ 58,  38,  31]],
#
#        ...,
#
#        [[189, 180, 141],
#         [190, 181, 142],
#         [186, 176, 140],
#         ...,
#         [170, 166, 118],
#         [161, 157, 109],
#         [161, 157, 109]],
#
#        [[206, 196, 160],
#         [201, 191, 155],
#         [182, 172, 136],
#         ...,
#         [171, 165, 117],
#         [172, 166, 118],
#         [172, 166, 118]],
#
#        [[207, 196, 164],
#         [205, 194, 162],
#         [180, 170, 135],
# ...

# %%
plt.imshow(sachinArray)

# %%
sachinArray.shape
# Out:
# (348, 474, 3)

# %%
featherArray = np.asarray(featherImage)
featherArray
# Out:
# array([[[24, 34, 46],
#         [17, 27, 39],
#         [18, 28, 40],
#         ...,
#         [ 6, 23, 30],
#         [ 6, 23, 30],
#         [15, 32, 39]],
#
#        [[14, 24, 36],
#         [ 7, 17, 29],
#         [ 9, 19, 31],
#         ...,
#         [ 1, 18, 25],
#         [ 1, 18, 25],
#         [ 9, 26, 33]],
#
#        [[14, 24, 36],
#         [ 7, 17, 29],
#         [ 9, 19, 31],
#         ...,
#         [ 0, 14, 21],
#         [ 0, 14, 21],
#         [ 6, 23, 30]],
#
#        ...,
#
#        [[ 8, 12, 15],
#         [ 1,  5,  8],
#         [ 3,  7, 10],
#         ...,
#         [ 0,  3, 14],
#         [ 0,  4, 15],
#         [ 8, 12, 23]],
#
#        [[ 6, 10, 13],
#         [ 0,  3,  6],
#         [ 0,  4,  7],
#         ...,
#         [ 0,  1, 12],
#         [ 0,  2, 13],
#         [ 6, 10, 21]],
#
#        [[15, 19, 22],
#         [ 8, 12, 15],
#         [ 9, 13, 16],
#         ...,
#         [ 6, 10, 21],
#         [ 7, 11, 22],
#         [15, 19, 30]]], dtype=uint8)

# %%
plt.imshow(featherArray)

# %%
featherArray.shape
# Out:
# (1543, 1200, 3)
