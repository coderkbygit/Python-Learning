# %% [markdown]
# Input Function

# %%
a = input('Enter a value') # by default Str only 
b = input('Enter a value')
c = a+b
print(c)
# Out:
# Enter a value 34
# Enter a value 43
# 3443

# %%
x2 = input('user name : ')
y2 = input('password : ')
z2= x2 + y2
print(z2)
# Out:
# user name :  hello
# password :  12345
# hello12345

# %%
st = input('enter a string')[1]
print(st)
# Out:
# enter a string hello
# e

# %%
res = int(input('enter an expr'))
print(res)
# Out:
# enter an expr 5+6-1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 res = int(input('enter an expr'))
#       2 print(res)
#
# ValueError: invalid literal for int() with base 10: '5+6-1'

# %%
res = eval(input('enter an expr'))
print(res)
# Out:
# enter an expr 3+9-1
# 11

# %%
import sys
print(sys.argv[1])
# Out:
# -f

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
